# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display, Math, Latex
from sympy import symbols, exp, integrate, oo, simplify
import sympy as sp

plt.rcParams['text.usetex'] = True

plt.style.use('seaborn-v0_8')

# %% [markdown]
# $$ \vec{v}_0 = {v_0}_x \ \hat{x} +  {v_0}_y \ \hat{y} $$
# $$ \vec{v}_0 = {v}_0 \cos{\theta_0} \ \hat{x} + {v}_0 \sin{\theta_0} \ \hat{y}$$

# %% [markdown]
# $$ x - x_0 = v_0 \cos{\theta_0}t $$
# $$ y - y_0 = v_0 \sin{\theta_0}t-\frac{1}{2}gt^2 $$
# $$ v_y = v_0 \sin{\theta_0} -gt $$
# $$ {v_y}^2 = (v_0 \sin{\theta_0})^2 -2g(y-y_0) $$
# $$ y = (\tan{\theta_0})x - \frac{gx^2}{2(v_0 cos{\theta_0})^2}$$
